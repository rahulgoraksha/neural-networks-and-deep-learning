# %% [markdown]
# ![image](https://media.geeksforgeeks.org/wp-content/uploads/20251213152654254872/ai_ml.webp)

# %% [markdown]
# Deep learning > only consist of the supervised learning one's
#
# Deep Learning: is a collection of statistical techniques of machine learning for learning features hierarchies that are actually based on artificial neural networks
#
# > Use Cases:
# 1. Text to Voice
# 2. Voice to Text
# 3. Image Segmentation
# 4. Autonomous Driving

# %% [markdown]
# ![neuron](https://media.geeksforgeeks.org/wp-content/uploads/20241106171024318092/Artificial-Neural-Networks.webp)

# %% [markdown]
# Neurons & Neural Networks:
#
# > Types of Deep Neural Network:
# 1. Perceptron
# 2. Feed Forward Networks
# 3. Mutli Layer Perceptron (ANN)
# 4. Radial Based Network
# 5. Convolution Neural Network (CNN)
# 6. Recurrent Neural Network (RNN)
# 7. Long Short Term Memory Network

# %% [markdown]
# Perceptron: single layer neural network or base layer neural network
