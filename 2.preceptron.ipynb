# %% [markdown]
# ## Preceptron

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mlxtend.

# %%
mlxtend.__version__
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 mlxtend.__version__
#
# NameError: name 'mlxtend' is not defined
